# %% [markdown]
# ### METODOS. Algunos ejemplos

# %% [markdown]
# Los métodos son funciones construidas en Python. ¡Ya hemos visto algunos en clase!
#
# Los métodos realizan acciones sobre un objeto y pueden tomar argumentos, como una función.
#
# Algunos ejemplos de métodos para las listas serían: **append()**, **count()**, **extend()**, **insert()**, **pop()**, **remove()**, **reverse()** o **sort()**.

# %%
lista = [1,2,3,4,5]

# %%
lista.append(6)
lista

# %%
lista.count(2)

# %%
help(lista.count)

# %% [markdown]
# ### FUNCIONES

# %% [markdown]
# Una función nos permite guardar bloques de código y ejecutarlos numerosas veces llamándolos por su nombre. De esta forma, no necesitamos escribir todo el código cada vez que queramos ejecutarlo.
#
# Podemos especificar unos parámetros que nos sirvan como input para las funciones. También podemos especificar los valores de salida que queramos.
#
# Las funciones se denominan con **def nombre_función(arg1,arg2):**

# %%
# Hacemos nuestra primera función
def di_hola():
    print('hola')

# %%
# Ahora llamamos a nuestra función
di_hola()

# %%
# Si no ponemos los paréntesis, vemos que nos dice que es una función
di_hola

# %%
# Podemos usar los argumentos
def saludos(nombre):
        print(f'Hola {nombre}')
saludos('Jose')

# %%
nombre='Lucía'

# %%
saludos(nombre)

# %%
# Podemos mostrar el output de una función con print() o con return. Return nos permite guardar el resultado en una variable
# Así ese resultado lo podemos usar para lo que queramos. 
# Con print no guardamos el resultado en una variable, solo lo mostramos.
def suma_numeros(n1,n2):
    if type(n1) == int and type(n2)== int:
        suma=n1+n2
        return suma

# %%
valor=suma_numeros(4,5)
valor

# %%
# También podemos hacer esto
resultado = suma_numeros(4,5)
resultado

# %%
# ¿Y si le metemos strings a suma_numeros?
suma_numeros('uno','dos')

# %%
suma_numeros('uno',4)

# %%
# Vamos a hacer una función que chequea si un número de una lista es par
# Para ello tenemos en cuenta que el módulo de un número par dividido entre 2 es igual a 0.
def es_par(lista_numeros):
    for numero in lista_numeros:
            if numero % 2 == 0:
                # si esta condición se cumple con return nos salimos de la lista
                return True
            else:
                pass

# %%
es_par([1,2,3])

# %%
# Sin embargo, si son todos impares no devuelve nada
es_par([1,3])

# %%
# Para corregirlo, podemos pensar que si añadirmos un return False, no? ¿Pero qué pasa si lo añadimos?
def es_par(lista_numeros):
    for numero in lista_numeros:
            if numero % 2 == 0:
                # si esta condición se cumple con return nos salimos de la lista
                return True
            else:
                return False

# %%
# Como el primero es impar, sale del bucle y ya no mira nada más
es_par([1,2,3])

# %%
# Esta sería una solución correcta
def es_par(lista_numeros):
    for numero in lista_numeros:
            if numero % 2 == 0:
                # si esta condición se cumple con return nos salimos de la lista
                return True
            else:
                pass
    # Cuando acaba de comprobar TODA la lista ahí sale del bloque
    return False

# %%
es_par([1,2,3])

# %%
es_par([1,3,7])

# %%
# Ahora vamos a por un ejemplo un poco más complicado. Queremos que nos devuelva TODOS los numeros pares en un lista. 
# Si no hay números pares, nos va a devolver la lista vacía
def es_par(lista_numeros):
    # Creamos una lista vacía
    lista_pares = []
    # Parseamos cada elemento de nuestro input:
    for numero in lista_numeros:
        if numero % 2 == 0:
            # Si esto es verdad, añadimos nuestro elemento a la lista
            lista_pares.append(numero)
        else:
            pass
    return lista_pares

# %%
es_par([1,2,3,4,5,6])

# %%
es_par([1,3,5,7,9])

# %%
# Vamos a crear ahora un pequeño juego. El jugador debe adivinar dónde está la letra "O"
# Empezamos creando una lista con tres elementos dónde la "O" se pone de forma aleatoria
from random import shuffle
mi_lista = [' ','O',' ']
def desordenar_lista(lista):
    shuffle(lista)
    return lista

desordenar_lista(mi_lista)
mi_lista

# %%
# Ahora el jugador tiene que adivinar dónde está. Para ello hacemos una función
def adivinacion():
    intento = ''
    while intento not in ['0','1','2']:
        intento = input("Esocoje un número: 0, 1, 2: ")
    return int(intento)

# %%
adivinacion()

# %%
# Ahora comprobamos el intento
def comprobacion(lista,intento):
    if lista[intento] == 'O':
        print('¡Has acertado!')
    else:
        print('¡Has fallado! Suerte para la próxima')
        print(lista)

# %%
# Ahora vamos a juntarlo todo
mi_lista = [' ','O',' ']
lista_desordenada=desordenar_lista(mi_lista)
intento = adivinacion()
comprobacion(lista_desordenada,intento)

# %% [markdown]
# ### Ejercicios de Funciones

# %% [markdown]
# #### 1.- El menor de dos pares. Escribe una función que devuelva el menor de dos números, SOLAMENTE si los dos números son pares. En caso de que uno de los dos, o los dos, sean impares, devuelve el número más alto

# %%
def menor_de_pares(n1,n2):
    if type(n1) == int and type(n2) == int:
        if n1 % 2 == 0 and n2 % 2 == 0:
            if n1 < n2:
                return n1
            else:
                return n2
        elif n1 % 2 != 0 or n2 % 2 != 0:
            if n1 > n2:
                return n1
            else:
                return n2
    else:
        print("No son números enteros")

# %%
menor_de_pares(7,"hola")
# Out:
# No son números enteros

# %%
def menor_de_pares(a,b):
    if a % 2 == 0 and b % 2 == 0:
        return min(a,b) 
    else:
        return max(a,b)

# %%
menor_de_pares(2,4)
# Out:
# 2

# %%
def menor_de_pares(a,b):
    if a % 2 == 0 and b % 2 == 0:
        return a if a < b else b
    return b if b < a else a

# %%
menor_de_pares(4,6)
# Out:
# 4

# %%
def menor_de_pares(a,b):
    if a % 2 == 0 and b % 2 == 0:
        if a > b:              
            return b           
        else:
            return a
    else:
        if a > b:
            return a
        else:
            return b

# %%
menor_de_pares(4,9)
# Out:
# 9

# %%
def menor_pares(lista_numeros):
    if len(lista_numeros) == 2:
        #iterar sobre la lista y comprobar si numero de posicion i y posicion i+1 son pares:
            if lista_numeros[i] % 2 == 0 and numeros+1 % 2:
                return min(lista_numeros)
            else:
                return max(lista_numeros)

# %%
def el_par_menor(n1,n2):
    if n1%2 == 0 and n2%2 == 0:
        return min(n1,n2)
    else:
        return max(n1,n2)

# %%
num1 = 9
num2 = 26

el_par_menor(num1,num2)

# %%
el_par_menor(4,5)

# %%
el_par_menor(8,10)

# %%
def el_par_menor(n1, n2):
    return min(n1, n2) if n1 % 2 == 0 and n2 % 2 == 0 else max(n1, n2)

# %% [markdown]
# #### 2.- Escribe una función que tome como argumento una string de dos palabras y devuelva True si ambas empiezan por la misma letra

# %%
frase = "algunas Asas"

# %%
def misma_letra(frase):
    lista_palabras = frase.split()
    if len(lista_palabras) == 2:
        if lista_palabras[0][0].lower() == lista_palabras[1][0].lower():
            return True
        else:
            return False
    else:
        print("Tu frase no tiene dos palabras. ERROR")

# %%
misma_letra(frase)
# Out:
# True

# %%
# esta no vale porque se introducen dos variables o palabras, queremos una frase de dos palabras, aún así quedaría si pidiese dos palabras
def misma_letra(palabra1,palabra2):
    if palabra1[0].lower() == palabra2[0].lower():
        return True
    else:
        return False

# %%
def misma_palabra(frase):
    lista_palabras = frase.split()
    if len(lista_palabras) == 2:
        if lista_palabras[0][0].lower() == lista_palabras[1][0].lower():
            return True
        else:
            print("Las palabras no empiezan por la misma letra")
    else:
        print("ERROR: Tu frase no tiene solamente dos palabras")

# %%
frase = "Bueno buenas"
misma_palabra(frase)
# Out:
# True

# %%
def misma_letra(palabra):
    word1,word2=palabra.split()
    if word1[0].lower() == word2[0].lower():
        return True
    else:
        return False

# %%
misma_letra("Perro pájaro")
# Out:
# True

# %%
misma_letra("perro gato")

# %%
def misma_letra(frase):
    palabras = frase.split()
    if len(palabras) == 2:
        return palabras[0][0].lower() == palabras[1][0].lower()
    else:
        print("Tu frase no tiene dos palabras exactas")

# %%
misma_letra("Perro pájaro")
# Out:
# True

# %%
mi_texto = ""

# %%
def dos_palabras(texto):
    texto_lista = texto.split()
    if len(texto_lista) == 2:
        if texto_lista[0][0] == texto_lista[1][0]:
            return True
        else:
            return False
    else:
        print('Incorrecto número de palabras')

# %%
dos_palabras(mi_texto)

# %%
def dos_palabras(text):
    lista_palabras = text.split()
    if len(lista_palabras)==2:
        if lista_palabras[0][0] == lista_palabras[1][0]:
            return True
        else:
            return False
    else:
        print('¡Tu string no tiene dos palabras!')
        return False

# %%
dos_palabras('Loca Llama')

# %%
dos_palabras('Llama')

# %%
dos_palabras('Volver Tiempo')

# %%
def dos_palabras(text):
    return len(text.split()) == 2 and text.split()[0][0] == text.split()[1][0]

# %% [markdown]
# #### 3.- Escribe una función que tome dos números enteros y que devuelva True si la suma de los dos es 20, o si uno de los dos es 20. Que devuelva Falso si no.

# %%
def suma_20(n1,n2):
    if type(n1) == int and type(n2) == int:
        suma = n1+n2
        if suma == 20 or n1 == 20 or n2 == 20:
            return True
        else:
            return False

# %%
def num_enteros(n1,n2):
    if n1+n2 == 20 or n1 == 20 or n2 == 20:
        return True
    else:
        return False

# %%
num_enteros(2,10)
# Out:
# False

# %%
def num_20 (a,b):
    if a + b == 20:
        return True
    elif a == 20 or b == 20:
        return True
    else:
        return False

# %%
num_20(10,3)
# Out:
# False

# %%
def num_20 (a,b):
    return a+b==20 or a==20 or b == 20

# %%
num_20(10,3)
# Out:
# False

# %%
def hacen_veinte(num1,num2):
    if num1+num2 == 20 or num1 == 20 or num2 == 20:
        return True
    else:
        return False

# %%
num1 = 10
num2 = 10
hacen_veinte(num1,num2)

# %%
def hacen_veinte(n1,n2):
    if (n1+n2)==20 or n1 == 20 or n2==20:
        return True
    else:
        return False
hacen_veinte(20,10)

# %%
hacen_veinte(12,8)

# %%
hacen_veinte(2,3)

# %%
def hacen_veinte(n1, n2):
    return (n1 + n2) == 20 or n1 == 20 or n2 == 20

# %% [markdown]
# #### 4.- Escribe una función que devuelva en mayúsculas la primera letra y la quinta letra de una palabra. Pista: usa capitalize()

# %%
palabra = "mARIposa"

# %%
def mayusculas(palabra):
    if len(palabra) >= 5:
        return palabra[0].capitalize()+palabra[1:4].lower()+palabra[4].capitalize()+palabra[5:].lower()
    else:
        pass

# %%
mayusculas(palabra)
# Out:
# 'MariPosa'

# %%
def letra_mayus(palabra):
    if len(palabra) < 5:
        print("ERROR: la palabra tiene que tener mínimo 5 letras")
    else:
        palabra_lower = palabra.lower()
        primera_parte = palabra_lower[0:4].capitalize()
        segunda_parte = palabra_lower[4:].capitalize()
        lista_final = primera_parte + segunda_parte
        return lista_final

# %%
letra_mayus("frigopie")
# Out:
# 'FrigOpie'

# %%
def mayus_1_5(palabra):
    if len(palabra) < 5 :
        return "La palabra es demasiado corta"
        #print("error")
        #return False
    primera = palabra[0].upper()
    medio = palabra[1:4]
    quinta = palabra[4].upper()
    resto = palabra[5:]

    return primera + medio + quinta + resto

# %%
mayus_1_5("baloncesto")
# Out:
# 'BaloNcesto'

# %%
palabra = 'Carromato'
# carRoMato

# %%
def algunas_mayus(palabra):
    palabra = palabra.lower()
    if len(palabra) > 4:
        return palabra[:3] + palabra[3:5].capitalize() + palabra[5:].capitalize()
    else:
        print('Tu palabra tiene que tener un mínimo de 5 caracteres')
    #palabra[0].capitalize() 
    #palabra[4].capitalize()

# %%
algunas_mayus(palabra)

# %%
def algunas_mayusculas(nombre):
    if len(nombre) > 4:
        return nombre[:4].capitalize() + nombre[4:].capitalize()
    else:
        return 'El nombre es muy corto'

# %%
algunas_mayusculas('dinosaurio')

# %%
def algunas_mayusculas(nombre):
    return (nombre[:4].capitalize() + nombre[4:].capitalize()) if len(nombre) > 4 else 'El nombre es muy corto'

# %% [markdown]
# #### 5.- Escribe una función que devuelva una frase invertida.

# %%
frase = input("Escribe una frase: ")
# Out:
# Escribe una frase:  Queremos irnos a casa

# %%
def maestro_yoda(frase):
    lista_frase = frase.split()
    return lista_frase[::-1]

# %%
maestro_yoda(frase)
# Out:
# ['casa', 'a', 'irnos', 'Queremos']

# %%
def invertida(frase):
    return frase[::-1]

# %%
invertida("Hola buenas qué tal")
# Out:
# 'lat éuq saneub aloH'

# %%
frase = 'Mi carro me lo robaron'
frase = frase.lower()

# %%
frase_lista = frase.split()
frase_lista = ' '.join(frase_lista[::-1])
frase_lista.capitalize()

# %%
cadena = 'ksldfjaskdlf'
cadena

# %%
cadena = cadena.capitalize()

# %%
cadena

# %%
def maestro_yoda(frase):
    frase=frase.lower()
    frase_lista = frase.split()
    frase_lista = ' '.join(frase_lista[::-1])
    return frase_lista.capitalize()

# %%
frase = "Hola buenas qué tal"
maestro_yoda(frase)
# Out:
# 'Tal qué buenas hola'

# %%
def maestro_yoda(frase):
    return ' '.join(frase.split()[::-1])

# %%
#frase='Aquí estoy'
#sep=frase.split()
#' '.join(sep)
#frase[::-1]
maestro_yoda('Estamos listos ya')

# %%
def maestro_yoda(frase):
    return ' '.join(frase.split()[::-1])

# %% [markdown]
# #### 6.- Dada una lista de enteros, devuelve True si contiene un 3 al lado de otro 3

# %%
list_num = [1,3,3,5,6]
len(list_num)
# Out:
# 5

# %%
for i in range(0,len(list_num)-1):
    if list_num[i] == 3 and list_num[i+1] == 3:
        print(True)
    else:
        print(False)
# Out:
# False
# True
# False
# False

# %%
def hay_33(lista):
    for i in range(0,len(lista)-1):
        if lista[i] == 3 and lista[i+1]==3:
            return True
    return False

# %%
hay_33([1,3,3])
# Out:
# True

# %%
hay_33([1,3,1,3])
# Out:
# False

# %%
def hay_33(lista):
    return any(lista[i] == lista[i+1] == 3 for i in range(len(lista) - 1))

# %%
def hay_33(lista):
    return "3, 3" in str(lista)

# %% [markdown]
# #### 7.- Escribe una función que busque numeros primos.

# %%
num=13

# %%
def es_primo(num):
    primo=True
    for i in range(2,num):
        if num%i == 0:
            print('No es primo')
            primo=False
            break
        else:
            continue
    return primo

# %%
num=12
es_primo(num)
# Out:
# No es primo
# False

# %%
def es_primo(n):
    
    for i in range(2,n):
        if n%i==0:
            print(n,'No es primo')
            break
        else:
            continue
    print(n,'Es primo')

# %%
es_primo(13)

# %%
es_primo(8)

# %%
def es_primo(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# %% [markdown]
# #### 8.- Juego de espías. Escribe una función que encuentre la secuencia 007 en una lista

# %%
lista=[1,2,4,0,0,7,5]

# %%
def es_espia(lista):
    espia=False
    for i in range(0,len(lista)-2):
        if lista[i]==0 and lista[i+1]==0 and lista[i+2]==7:
            espia=True
    return espia

# %%
es_espia(lista)

# %%
lista_string = ''.join(str(lista))

lista_string
code='007'

lista_string

# %%
nueva_string=''
for i in str(lista):
    nueva_string += i
nueva_string

# %%
def juego_espias(lista):
    code=[0,0,7,'x']
    for i in lista:
        if i == code[0]:
            code.remove(i)
            #code.pop(0)
    return len(code)==1

# %%
juego_espias([1,2,4,0,0,7,5])

# %%
juego_espias([1,2,4,0,7,5,6])

# %%
def juego_espias(lista):
    code = [0, 0, 7]
    it = iter(lista)
    return all(c in it for c in code)

# %%
def juego_espias(lista):
    code = [0, 0, 7]
    pos = 0
    for num in lista:
        if pos < len(code) and num == code[pos]:
            pos += 1
    return pos == len(code)

# %% [markdown]
# #### 9.- Juego de BLACKJACK. Dados tres numeros enteros entre el 1 y el 11, si su suma es menor o igual que 21, devuelve su suma. Si su suma es mayor que 21 y hay un 11, resta 10 al total de la suma. Finalmente, si con el ajuste es mayor que 21, se devuelve BUST.
# ##### 5,6,7 =18
# ##### 9,9,9 = BUST
# ##### 9,9,11 = 19

# %%
a=8
b=7
c=6
if a>11 or b>11 or c>11 or a==0 or b==0 or c==0 and type(a)!=int and type(b)!=int and type(c)!=int:
    print('ERROR: Fuera de rango')
else:
    suma=a+b+c
    if suma <= 21:
        print(suma)
    elif suma > 21:
        if a == 11 or b == 11 or c == 11:
            suma -= 10
            if suma > 21:
                print('BUST')

# %%
a = 10
b=5
c=6

if a>11 or b>11 or c>11 or a==0 or b==0 or c==0 and type(a)!=int and type(b)!=int and type(c)!=int:
    print('ERROR: Fuera de rango')
else:
    suma = a+b+c
    if suma <= 21:
        return suma
    elif suma > 21:
        if a==11 or b==11 or c==11:
            suma -= 10
            if suma > 21:
                print('BUST')

# %%
def blackjack(a,b,c):
    # Primero comprobamos que ninguno de los numeros sea mayor que 11 o 0
    if a>11 or b>11 or c>11 or a==0 or b==0 or c==0:
        return 'Números fuera de rango'
    else:
        # Ahora calculamos la suma. Hay que poner doble paréntesis para que sum() pille más de dos argumentos
        suma=sum((a,b,c))
        if suma <= 21:
            return suma
        elif suma <= 31 and 11 in (a,b,c):
            return suma - 10
        else:
            return 'BUST'

# %%
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
blackjack(5,6,7)

# %%
blackjack(9,9,11)

# %%
blackjack(0,2,3)

# %%
blackjack(2,5,34)

# %%
def blackjack(a, b, c):
    valores = (a, b, c)
    if any(n > 11 or n == 0 for n in valores):
        return "Números fuera de rango"
    
    suma = sum(valores)
    if suma <= 21:
        return suma
    if suma <= 31 and 11 in valores:
        return suma - 10
    return "BUST"
