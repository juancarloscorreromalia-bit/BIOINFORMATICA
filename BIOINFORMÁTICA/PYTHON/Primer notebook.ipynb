# %% [markdown]
# # PRIMER NOTEBOOK

# %% [markdown]
# ## Este es mi primer notebook y voy a hacer lo siguiente

# %% [markdown]
# Una lista **enumerada**

# %% [markdown]
# 1. primero
# 2. segundo
# 3. tercero
# 4. cuarto

# %% [markdown]
# Una lista **por puntos**

# %% [markdown]
# - primero
# - segundo
# - tercero
# - cuarto

# %% [markdown]
# Mi primer **codigo**

# %%
mi_primera_frase= "me cago en dios"

# %%
print(mi_primera_frase)
# Out:
# me cago en dios

# %%
numeros= (5,10,15,20,25,30)

# %%
media = sum(numeros) /len(numeros)

# %%
print(media)
# Out:
# 17.5

# %% [markdown]
# ![amigdalaa.png](amigdalaa.png)
